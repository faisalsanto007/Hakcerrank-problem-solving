# %% [markdown]
# ### the weighted mean is the mean of the each value when it is multiplied by some weight wi

# %% [markdown]
# ![weighted%20mean.PNG](attachment:weighted%20mean.PNG)

# %%
# soln

size = int(input())
numbers = list(map(int, input().split()))
weighted = list(map(int, input().split()))

sum_items = 0
for i in range(size):
    sum_items = sum_items + (numbers[i] * weighted[i])

print(round(sum_items/sum(weighted), 1))
# Out:
# 5
# 10 40 30 50 20
# 1 2 3 4 5
# 32.0
